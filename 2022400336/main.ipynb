# %%
import descriptor

# paths
imgs_root_path = '../data/Images'
test_images_txt_path = '../data/TestImages.txt'
train_images_txt_path = '../data/TrainImages.txt'

# getting descriptors of TestImages.txt
descriptor.extract_sift_features(test_images_txt_path, imgs_root_path)

# getting descriptors of TrainImages.txt
descriptor.extract_sift_features(train_images_txt_path, imgs_root_path)

# %%
import descriptor

# paths
imgs_root_path = '../data/Images'
test_images_txt_path = '../data/TestImages.txt'
train_images_txt_path = '../data/TrainImages.txt'

# getting descriptors of TestImages.txt
descriptor.extract_swin_b_features(test_images_txt_path, imgs_root_path)

# getting descriptors of TrainImages.txt
descriptor.extract_swin_b_features(train_images_txt_path, imgs_root_path)
# Out:
# Downloading: "https://download.pytorch.org/models/swin_b-68c6b09e.pth" to /home/amin/.cache/torch/hub/checkpoints/swin_b-68c6b09e.pth
# 100.0%
# [OK] Saved (7168, 7) descriptors for kitchen/int474.jpg
# [OK] Saved (7168, 7) descriptors for operating_room/operating_room_31_03_altavista.jpg
# [OK] Saved (7168, 7) descriptors for restaurant_kitchen/restaurant_kitchen_google_0075.jpg
# [OK] Saved (7168, 7) descriptors for videostore/videoclub_05_14_flickr.jpg
# [OK] Saved (7168, 7) descriptors for poolinside/piscine_interieureee.jpg
# [OK] Saved (7168, 7) descriptors for videostore/blockbuster_08_10_flickr.jpg
# [OK] Saved (7168, 7) descriptors for poolinside/piscina_cubierta_07_19_altavista.jpg
# [OK] Saved (7168, 7) descriptors for mall/mall26.jpg
# [OK] Saved (7168, 7) descriptors for kindergarden/toddler.jpg
# [OK] Saved (7168, 7) descriptors for buffet/Buffet_1.jpg
# [OK] Saved (7168, 7) descriptors for hospitalroom/IMG_1482.jpg
# ...

# %%
import feature_quantisation as fq
# --- 2. Quantization & Histogram building ---
fq.run_feature_quantization(
    train_list = '../data/TrainImages.txt',
    test_list = '../data/TestImages.txt',
    sift_desc_dir = '../data/descriptors/sift',
    swin_desc_dir = None,
    sift_hist_dir = '../data/histograms/sift',
    swin_hist_dir = None,
    ks=[50, 100, 500]
)
# Out:
# [INFO] Feature quantisation for K = 50....
